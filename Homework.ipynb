# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r', encoding = "ANSI")

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
next(archivo)
for linea in archivo:
    campos = linea.strip().split("|")
    dicc_emisiones["cod_pais"].append(campos[0])
    dicc_emisiones["nom_pais"].append(campos[1])
    dicc_emisiones["region"].append(campos[2])
    dicc_emisiones["anio"].append(campos[3])
    dicc_emisiones["co2"].append(campos[4])
    dicc_emisiones["co2_percapita"].append(campos[5])

# %%
archivo.close()

# %% [markdown]
# ### a) ¿Cuántas variables hay? <br>

# %%
print(f"hay {len(dicc_emisiones.keys())} variables en el CVS")
# Out:
# hay 6 variables en el CVS

# %% [markdown]
# ### b) ¿Qué tipos de datos usar para cada una? <br>

# %% [markdown]
# 1- cod_pais: Cualitativo nominal
# 2- nom_pais:Cualitativo nominal
# 3- region: Cualitatigo nominal
# 4- anio:Cualitativo ordinal
# 5- co2: Cuantitativo continuo
# 6- co2_percapita: Cuantitativo continuo

# %% [markdown]
# ### c) ¿Qué tipo de variables son? <br>

# %%
for valores in dicc_emisiones.values():
    print(f"el dato {valores[4]} es de tipo {type(valores[4])}")
# Out:
# el dato ABW es de tipo <class 'str'>
# el dato Aruba es de tipo <class 'str'>
# el dato América Latina y Caribe es de tipo <class 'str'>
# el dato 1964 es de tipo <class 'str'>
# el dato  es de tipo <class 'str'>
# el dato  es de tipo <class 'str'>

# %% [markdown]
# ### d) ¿Hay valores faltantes? <br>

# %%
def contar_nulos(variable):
    nulo = 0
    for i in variable:
        if i == "":
            nulo += 1
        
    return nulo

# %%
faltantes = 0
for llave in dicc_emisiones.keys():
    nulos = contar_nulos(dicc_emisiones[llave])
    faltantes = faltantes + nulos
    
print(f"la cantidad de nulos es {faltantes}")
# Out:
# la cantidad de nulos es 4193

# %% [markdown]
# ### e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %%
dicc_emisiones["co2"] = [float(elemento.replace(".", "").replace(",", "."))if elemento != "" else None for elemento in dicc_emisiones["co2"]]

# %%
emisiones = float(0)
for indice, region in enumerate(dicc_emisiones["region"]):

    if region == "América Latina y Caribe" and dicc_emisiones["anio"][indice] == "2010":
        if dicc_emisiones["co2"][indice] != None:
            co2 = dicc_emisiones["co2"][indice]
            emisiones = emisiones + co2
print(f"La suma de las emisiones de co2 es: {emisiones}")

emisiones2 = float(0)
for indice, region in enumerate(dicc_emisiones["region"]):

    if region == "América Latina y Caribe" and dicc_emisiones["anio"][indice] == "2010":
        if dicc_emisiones["co2_percapita"][indice] != None:
            co2_percapita = dicc_emisiones["co2_percapita"][indice]
            emisiones2 = emisiones2 + co2
print(f"La suma de las emisiones de Co2 percepita es: {emisiones2}")
# Out:
# La suma de las emisiones de co2 es: 1691634.8009999995
# La suma de las emisiones de Co2 percepita es: 8097989.950000005
